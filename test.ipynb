# %%
import pandas as pd

# %%
df = pd.read_csv("complaint_data.csv")

# %%
df.head(20)
# Out:
#    Date received                                            Product  \
# 0     08/09/2015                                   Credit reporting
# 1     12/23/2019                                       Student loan
# 2     01/29/2019  Credit reporting, credit repair services, or o...
# 3     08/19/2015                                           Mortgage
# 4     03/04/2016                                        Credit card
# 5     03/18/2013                                           Mortgage
# 6     12/21/2011                                           Mortgage
# 7     10/24/2018  Credit reporting, credit repair services, or o...
# 8     03/03/2018  Credit reporting, credit repair services, or o...
# 9     01/02/2019                                    Debt collection
# 10    12/23/2018  Credit reporting, credit repair services, or o...
# 11    09/12/2016                            Bank account or service
# 12    04/13/2018                        Credit card or prepaid card
# ...

# %%
df_new = df.drop(columns = {"State", "ZIP code", "Tags", "Consumer consent provided?",	"Submitted via", "Date sent to company", "Timely response?", "Consumer disputed?"})

# %%
df_new.head(20)
# Out:
#    Date received                                            Product  \
# 0     08/09/2015                                   Credit reporting
# 1     12/23/2019                                       Student loan
# 2     01/29/2019  Credit reporting, credit repair services, or o...
# 3     08/19/2015                                           Mortgage
# 4     03/04/2016                                        Credit card
# 5     03/18/2013                                           Mortgage
# 6     12/21/2011                                           Mortgage
# 7     10/24/2018  Credit reporting, credit repair services, or o...
# 8     03/03/2018  Credit reporting, credit repair services, or o...
# 9     01/02/2019                                    Debt collection
# 10    12/23/2018  Credit reporting, credit repair services, or o...
# 11    09/12/2016                            Bank account or service
# 12    04/13/2018                        Credit card or prepaid card
# ...

# %%
df_new.shape
# Out:
# (1471766, 10)
